# %%
from twitter import *
import json

# %%
AccessToken = '970079621499666432-3POTnYxZ2awfyGK6mDGhEgstmqwm3Wb'
AccessTokenSecret = 'y1FCKiRbdtPOAaqQ2NYNGHfG4KUmTRxcw4nvU7L1fR6XR'
ConsumerKey = '4XhYIbd8WzvK5KBBrtcpfIlO3'
ConsumerSecret = 'UYFBYawOQ3pltJrqklSUZnElamk61Jd7krMEMAjDnssnMrPB91'


t = Twitter(auth=OAuth(AccessToken, AccessTokenSecret, 
                       ConsumerKey, ConsumerSecret))

# %%
# get tweets and convert to JSON format
AmazonJSON = json.dumps(t.search.tweets(q='#Amazon'))

# %%
# deal with json data
tweets = json.loads(AmazonJSON)

# %%
tweets
# Out:
# {'search_metadata': {'completed_in': 0.044,
#   'count': 15,
#   'max_id': 986759726309564420,
#   'max_id_str': '986759726309564420',
#   'query': '%23Amazon',
#   'refresh_url': '?since_id=986759726309564420&q=%23Amazon&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Apr 19 00:13:46 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/986759726309564420',
#       'indices': [116, 139],
#       'url': 'https://t.co/AFunFKUhXs'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 986759726309564420,
#    'id_str': '986759726309564420',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://semanticearth.com" rel="nofollow">Promotion Amazon2</a>',
#    'text': '12% off, 4.1 Stars, 1270 Reviews: Seagate Backup Plus External Desktop Hard Drive Storage  Adobe. Top Review said:… https://t.co/AFunFKUhXs',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Sep 10 16:25:01 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Promoting great articles and retweets about #ClimateChange. Topics in #meteorology #climate #polution among others. Powered by @SemanticEarth',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 39,
#     'follow_request_sent': False,
#     'followers_count': 1302,
#     'following': False,
#     'friends_count': 81,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 906916431563911169,
#     'id_str': '906916431563911169',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 31,
#     'location': 'Global',
#     'name': 'Climate Change',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/906916431563911169/1505061135',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/906917905543061504/WATkHgwO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/906917905543061504/WATkHgwO_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Climate_ch',
#     'statuses_count': 109893,
#     'time_zone': 'Caracas',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Apr 19 00:13:43 +0000 2018',
#    'entities': {'hashtags': [{'indices': [14, 26], 'text': 'AmazonPrime'},
#      {'indices': [38, 45], 'text': 'Amazon'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/wsj/status/986…',
#       'expanded_url': 'https://twitter.com/wsj/status/986729534790750208',
#       'indices': [46, 69],
#       'url': 'https://t.co/5WTBA2bPuO'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 986759713181270016,
#    'id_str': '986759713181270016',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Apr 18 22:13:48 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'on.wsj.com/2EXAdB9',
#        'expanded_url': 'https://on.wsj.com/2EXAdB9',
#        'indices': [106, 129],
#        'url': 'https://t.co/5GR99RaJu4'}],
#      'user_mentions': []},
#     'favorite_count': 229,
#     'favorited': False,
#     'geo': None,
#     'id': 986729534790750208,
#     'id_str': '986729534790750208',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 122,
#     'retweeted': False,
#     'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#     'text': 'Amazon revealed for the first time that it has more than 100 million members paying for its Prime service\nhttps://t.co/5GR99RaJu4',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Apr 01 06:22:13 +0000 2007',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Breaking news and features from the WSJ.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'wsj.com',
#          'expanded_url': 'http://wsj.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/GhhR6PLfem'}]}},
#      'favourites_count': 1285,
#      'follow_request_sent': False,
#      'followers_count': 15759063,
#      'following': False,
#      'friends_count': 1108,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 3108351,
#      'id_str': '3108351',
#      'is_translation_enabled': True,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 109215,
#      'location': 'New York, NY',
#      'name': 'The Wall Street Journal',
#      'notifications': False,
#      'profile_background_color': 'EDF2F5',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000026078008/c07ad7d60f01c3a836dd701fc3f71233.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000026078008/c07ad7d60f01c3a836dd701fc3f71233.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3108351/1516021057',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/971415515754266624/zCX0q9d5_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/971415515754266624/zCX0q9d5_normal.jpg',
#      'profile_link_color': '1164B8',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'WSJ',
#      'statuses_count': 240476,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'regular',
#      'url': 'https://t.co/GhhR6PLfem',
#      'utc_offset': -14400,
#      'verified': True}},
#    'quoted_status_id': 986729534790750208,
#    'quoted_status_id_str': '986729534790750208',
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "That's great! #AmazonPrime is so dope #Amazon https://t.co/5WTBA2bPuO",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jul 31 02:51:07 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Redskins | Wizards | Nationals | Capitals',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 642,
#     'follow_request_sent': False,
#     'followers_count': 167,
#     'following': False,
#     'friends_count': 129,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 345736094,
#     'id_str': '345736094',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 5,
#     'location': 'Washington, DC',
#     'name': 'YønasMekønen',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/345736094/1460564786',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/964695389764022272/SfvuXGDc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964695389764022272/SfvuXGDc_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'yonasmekonen',
#     'statuses_count': 9364,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Apr 19 00:13:40 +0000 2018',
#    'entities': {'hashtags': [{'indices': [76, 83], 'text': 'gaming'},
#      {'indices': [84, 91], 'text': 'Amazon'}],
#     'symbols': [],
#     'urls': [{'display_url': 'search.app.goo.gl/F6hCV',
#       'expanded_url': 'https://search.app.goo.gl/F6hCV',
#       'indices': [92, 115],
#       'url': 'https://t.co/gBylJtvtdI'}],
#     'user_mentions': [{'id': 27491863,
#       'id_str': '27491863',
#       'indices': [3, 15],
#       'name': 'sB',
#       'screen_name': 'bboyoninsta'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 986759699319148545,
#    'id_str': '986759699319148545',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Apr 18 23:05:54 +0000 2018',
#     'entities': {'hashtags': [{'indices': [59, 66], 'text': 'gaming'},
#       {'indices': [67, 74], 'text': 'Amazon'}],
#      'symbols': [],
#      'urls': [{'display_url': 'search.app.goo.gl/F6hCV',
#        'expanded_url': 'https://search.app.goo.gl/F6hCV',
#        'indices': [75, 98],
#        'url': 'https://t.co/gBylJtvtdI'}],
#      'user_mentions': []},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 986742646008885249,
#     'id_str': '986742646008885249',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': {'attributes': {},
#      'bounding_box': {'coordinates': [[[-85.605166, 30.355644],
#         [-80.742567, 30.355644],
#         [-80.742567, 35.000771],
#         [-85.605166, 35.000771]]],
#       'type': 'Polygon'},
#      'contained_within': [],
#      'country': 'United States',
#      'country_code': 'US',
#      'full_name': 'Georgia, USA',
#      'id': '7142eb97ae21e839',
#      'name': 'Georgia',
#      'place_type': 'admin',
#      'url': 'https://api.twitter.com/1.1/geo/id/7142eb97ae21e839.json'},
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Alexa can help improve your ‘Call of Duty: WWII’ K/D ratio #gaming\n#Amazon\nhttps://t.co/gBylJtvtdI',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Mar 29 20:01:52 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Saving and improving men’s lives through projects focused on prostate cancer, testicular cancer, mental health and suicide prevention..  https://t.co/cHI3NVs8eO',
#      'entities': {'description': {'urls': [{'display_url': 'moteam.co/nguvu',
#          'expanded_url': 'https://moteam.co/nguvu',
#          'indices': [137, 160],
#          'url': 'https://t.co/cHI3NVs8eO'}]},
#       'url': {'urls': [{'display_url': 'Instagram.com/bboyoninsta',
#          'expanded_url': 'https://Instagram.com/bboyoninsta',
#          'indices': [0, 23],
#          'url': 'https://t.co/tZ2F6aHAug'}]}},
#      'favourites_count': 11223,
#      'follow_request_sent': False,
#      'followers_count': 718,
#      'following': False,
#      'friends_count': 451,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 27491863,
#      'id_str': '27491863',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 87,
#      'location': 'Georgia, USA',
#      'name': 'sB',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27491863/1508014368',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/930529298217398272/DdlxK9zf_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/930529298217398272/DdlxK9zf_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'bboyoninsta',
#      'statuses_count': 73946,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'https://t.co/tZ2F6aHAug',
#      'utc_offset': -14400,
#      'verified': False}},
#    'source': '<a href="http://cinchtweet.com" rel="nofollow">gamezone-app</a>',
#    'text': 'RT @bboyoninsta: Alexa can help improve your ‘Call of Duty: WWII’ K/D ratio #gaming\n#Amazon\nhttps://t.co/gBylJtvtdI',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Feb 22 13:14:39 +0000 2018',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 3237,
#     'follow_request_sent': False,
#     'followers_count': 131,
#     'following': False,
#     'friends_count': 268,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 966662521028468737,
#     'id_str': '966662521028468737',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'id',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Game Zone',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/966662521028468737/1519306024',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/966664840176545795/NEVPPxaw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/966664840176545795/NEVPPxaw_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'gamer_zone2',
#     'statuses_count': 1901,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Apr 19 00:13:27 +0000 2018',
#    'entities': {'hashtags': [{'indices': [68, 75], 'text': 'amazon'}],
#     'symbols': [],
#     'urls': [{'display_url': 'crwd.fr/2EiWBVh',
#       'expanded_url': 'https://crwd.fr/2EiWBVh',
#       'indices': [77, 100],
#       'url': 'https://t.co/NEK86qEwLD'},
#      {'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/986759644956815360',
#       'indices': [117, 140],
#       'url': 'https://t.co/JyvYLWNoQ8'}],
#     'user_mentions': [{'id': 325457018,
#       'id_str': '325457018',
#       'indices': [51, 67],
#       'name': 'Nicolas Lopez',
#       'screen_name': 'ContratameYGana'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 986759644956815360,
#    'id_str': '986759644956815360',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.crowdfireapp.com" rel="nofollow">Crowdfire - Go Big</a>',
#    'text': 'Apuesta equivocada: cuando la diplomacia falla\nby: @ContratameYGana\n#amazon: https://t.co/NEK86qEwLD  \nIntriga, acc… https://t.co/JyvYLWNoQ8',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Apr 30 02:56:47 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#Blogger literaria, publicista. Si deseas publicidad o portadas escribe a soltaylor.rdl@gmail.com',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'rebeliondelibros.blogspot.com',
#         'expanded_url': 'http://rebeliondelibros.blogspot.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/tjK35ISqXa'}]}},
#     'favourites_count': 6562,
#     'follow_request_sent': False,
#     'followers_count': 16315,
#     'following': False,
#     'friends_count': 10927,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 138627969,
#     'id_str': '138627969',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 415,
#     'location': '',
#     'name': 'Sol Taylor',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/138627969/1466096607',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/794314402673676294/tmaCDUv__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/794314402673676294/tmaCDUv__normal.jpg',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'SolTaylorRdL',
#     'statuses_count': 121767,
#     'time_zone': 'Buenos Aires',
#     'translator_type': 'none',
#     'url': 'https://t.co/tjK35ISqXa',
#     'utc_offset': -10800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Apr 19 00:13:11 +0000 2018',
#    'entities': {'hashtags': [{'indices': [0, 8], 'text': 'Zombies'},
#      {'indices': [11, 20], 'text': 'vampiros'},
#      {'indices': [32, 46], 'text': 'SantJordi2018'},
#      {'indices': [76, 83], 'text': 'libros'},
#      {'indices': [102, 109], 'text': 'horror'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/986759579945009153',
#       'indices': [111, 134],
#       'url': 'https://t.co/FcDfGribOr'}],
#     'user_mentions': [{'id': 2941435095,
#       'id_str': '2941435095',
#       'indices': [87, 100],
#       'name': 'El Panda Cinéfilo',
#       'screen_name': 'medinabotija'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 986759579945009153,
#    'id_str': '986759579945009153',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.crowdfireapp.com" rel="nofollow">Crowdfire - Go Big</a>',
#    'text': '#Zombies y #vampiros invaden el #SantJordi2018 \nNo te pierdas las firmas de #libros de @medinabotija \n#horror… https://t.co/FcDfGribOr',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Apr 30 02:56:47 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#Blogger literaria, publicista. Si deseas publicidad o portadas escribe a soltaylor.rdl@gmail.com',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'rebeliondelibros.blogspot.com',
#         'expanded_url': 'http://rebeliondelibros.blogspot.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/tjK35ISqXa'}]}},
#     'favourites_count': 6562,
#     'follow_request_sent': False,
#     'followers_count': 16315,
#     'following': False,
#     'friends_count': 10927,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 138627969,
#     'id_str': '138627969',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 415,
#     'location': '',
#     'name': 'Sol Taylor',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/138627969/1466096607',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/794314402673676294/tmaCDUv__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/794314402673676294/tmaCDUv__normal.jpg',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'SolTaylorRdL',
#     'statuses_count': 121767,
#     'time_zone': 'Buenos Aires',
#     'translator_type': 'none',
#     'url': 'https://t.co/tjK35ISqXa',
#     'utc_offset': -10800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Apr 19 00:13:10 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 917562993818337281,
#       'id_str': '917562993818337281',
#       'indices': [3, 18],
#       'name': '♕ᑕᕼIᗰEᖇᗩ♕',
#       'screen_name': 'ChimeraEmbrace'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 986759577311080448,
#    'id_str': '986759577311080448',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 2,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Apr 18 22:10:48 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/986728780227112960',
#        'indices': [117, 140],
#        'url': 'https://t.co/Y134RoIzuV'}],
#      'user_mentions': []},
#     'favorite_count': 2,
#     'favorited': False,
#     'geo': None,
#     'id': 986728780227112960,
#     'id_str': '986728780227112960',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 2,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'I want something to be clear this means it includes all of whag it says in the description bc one of my friend said… https://t.co/Y134RoIzuV',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Oct 10 01:30:40 +0000 2017',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'emanxkowsar page',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 83,
#      'follow_request_sent': False,
#      'followers_count': 33,
#      'following': False,
#      'friends_count': 85,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 917562993818337281,
#      'id_str': '917562993818337281',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 1,
#      'location': 'United States',
#      'name': '♕ᑕᕼIᗰEᖇᗩ♕',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/917562993818337281/1507601086',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/917572018119299072/60GR8L89_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917572018119299072/60GR8L89_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'ChimeraEmbrace',
#      'statuses_count': 65,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @ChimeraEmbrace: I want something to be clear this means it includes all of whag it says in the description bc one of my friend said its…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat May 20 02:34:23 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '🌸✨EXTRA + ORDINARY✨🌸',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 8796,
#     'follow_request_sent': False,
#     'followers_count': 482,
#     'following': False,
#     'friends_count': 2202,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 865757566248382464,
#     'id_str': '865757566248382464',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': 'United States',
#     'name': '하브진',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/865757566248382464/1522941889',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/980780728635023360/2u1WXndV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/980780728635023360/2u1WXndV_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'x7jinnie7x',
#     'statuses_count': 8039,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}}]}

# %%
TweetsList = list(tweets.values())

# %%
len(TweetsList)
# Out:
# 2

# %%
len(TweetsList[0])
# Out:
# 6

# %%
len(TweetsList[1])
# Out:
# 8

# %%
type(TweetsList[0][0])
# Out:
# dict

# %%
len(TweetsList[0][0])
# Out:
# 25

# %%
TweetsList[0][0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
TweetsList[0][0]['text']
# Out:
# '12% off, 4.1 Stars, 1270 Reviews: Seagate Backup Plus External Desktop Hard Drive Storage  Adobe. Top Review said:… https://t.co/AFunFKUhXs'

# %%
for i in range(len(TweetsList[0])):
    print(TweetsList[0][i]['created_at'])
    print(TweetsList[0][i]['text'])
# Out:
# Thu Apr 19 00:13:46 +0000 2018
# 12% off, 4.1 Stars, 1270 Reviews: Seagate Backup Plus External Desktop Hard Drive Storage  Adobe. Top Review said:… https://t.co/AFunFKUhXs
# Thu Apr 19 00:13:43 +0000 2018
# That's great! #AmazonPrime is so dope #Amazon https://t.co/5WTBA2bPuO
# Thu Apr 19 00:13:40 +0000 2018
# RT @bboyoninsta: Alexa can help improve your ‘Call of Duty: WWII’ K/D ratio #gaming
# #Amazon
# https://t.co/gBylJtvtdI
# Thu Apr 19 00:13:27 +0000 2018
# Apuesta equivocada: cuando la diplomacia falla
# by: @ContratameYGana
# #amazon: https://t.co/NEK86qEwLD
# Intriga, acc… https://t.co/JyvYLWNoQ8
# Thu Apr 19 00:13:11 +0000 2018
# #Zombies y #vampiros invaden el #SantJordi2018
# No te pierdas las firmas de #libros de @medinabotija
# #horror… https://t.co/FcDfGribOr
# Thu Apr 19 00:13:10 +0000 2018
# RT @ChimeraEmbrace: I want something to be clear this means it includes all of whag it says in the description bc one of my friend said its…
