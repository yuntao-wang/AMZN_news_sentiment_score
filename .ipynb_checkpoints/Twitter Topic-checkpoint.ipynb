# %%
from twitter import *
import json

# %%
AccessToken = '970079621499666432-3POTnYxZ2awfyGK6mDGhEgstmqwm3Wb'
AccessTokenSecret = 'y1FCKiRbdtPOAaqQ2NYNGHfG4KUmTRxcw4nvU7L1fR6XR'
ConsumerKey = '4XhYIbd8WzvK5KBBrtcpfIlO3'
ConsumerSecret = 'UYFBYawOQ3pltJrqklSUZnElamk61Jd7krMEMAjDnssnMrPB91'


t = Twitter(auth=OAuth(AccessToken, AccessTokenSecret, 
                       ConsumerKey, ConsumerSecret))

# %%
# get tweets and convert to JSON format
AmazonJSON = json.dumps(t.search.tweets(q='#Amazon'))

# %%
# deal with json data
techTweets = json.loads(techJSON)

# %%
techTweets
# Out:
# {'search_metadata': {'completed_in': 0.043,
#   'count': 15,
#   'max_id': 970113865676722176,
#   'max_id_str': '970113865676722176',
#   'query': '%23tech',
#   'refresh_url': '?since_id=970113865676722176&q=%23tech&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 04 01:49:04 +0000 2018',
#    'entities': {'hashtags': [{'indices': [45, 50], 'text': 'VRLA'},
#      {'indices': [107, 110], 'text': 'VR'},
#      {'indices': [111, 114], 'text': 'AR'},
#      {'indices': [115, 120], 'text': 'Tech'}],
#     'symbols': [],
#     'urls': [{'display_url': 'huffingtonpost.com/jesse-damiani/…',
#       'expanded_url': 'http://www.huffingtonpost.com/jesse-damiani/the-best-of-the-best-at-vrla-summer-expo_b_11439342.html',
#       'indices': [64, 87],
#       'url': 'https://t.co/Td525SqKKH'}],
#     'user_mentions': [{'id': 1469573318,
#       'id_str': '1469573318',
# ...

# %%
techList = list(techTweets.values())

# %%
len(techList)
# Out:
# 2

# %%
len(techList[0])
# Out:
# 12

# %%
len(techList[1])
# Out:
# 8

# %%
type(techList[0][0])
# Out:
# dict

# %%
len(techList[0][0])
# Out:
# 25

# %%
techList[0][0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
techList[0][0]['text']
# Out:
# 'RT @Fisher85M: This 3D Printer can print metal in the air! {Video}\n\n#3Dprinting #innovation #tech #Industry40 #sensors #HealthIT #Manufactu…'

# %%
for i in range(len(techList[0])):
    print(techList[0][i]['created_at'])
    print(techList[0][i]['text'])
# Out:
# Sun Mar 04 01:59:07 +0000 2018
# RT @Fisher85M: This 3D Printer can print metal in the air! {Video}
#
# #3Dprinting #innovation #tech #Industry40 #sensors #HealthIT #Manufactu…
# Sun Mar 04 01:59:06 +0000 2018
# Top 25 Robot Trends in March - From Low-Tech Robotics Kits to Robot Warehouse Workers https://t.co/TENnliYSVw #Tech https://t.co/Y8fjbFEdGf
# Sun Mar 04 01:59:06 +0000 2018
# RT DeepLearn007 "RT DeepLearn007: Key Machine Learning Trends That Will Rock Your 2018
# #AI #MachineLearning… https://t.co/u1PR8EZVdB
# Sun Mar 04 01:58:53 +0000 2018
# RT @delizalde: How to Reduce Cost and Boost Quality with an IoT Platform https://t.co/M3PAx9EA0Y #IoT #Prodmgmt #IIoT #Tech #InternetOfThin…
# Sun Mar 04 01:58:52 +0000 2018
# RT @Fisher85M: This 3D Printer can print metal in the air! {Video}
#
# #3Dprinting #innovation #tech #Industry40 #sensors #HealthIT #Manufactu…
# Sun Mar 04 01:58:43 +0000 2018
# ...
